# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#set file paths and read in files
filepath = '../raw_data/MN_walkability.csv'
statepath = '../raw_data/state_and_county_fips_master.csv'
healthpath = '../raw_data/MN_health_data.csv'
minnesota = pd.read_csv(filepath)
states = pd.read_csv(statepath)
health = pd.read_csv(healthpath)
health.head()
# Out:
#     fips      State    County Unreliable   Deaths  \
# 0  27000  Minnesota       NaN        NaN  55372.0
# 1  27001  Minnesota    Aitkin        NaN    277.0
# 2  27003  Minnesota     Anoka        NaN   3321.0
# 3  27005  Minnesota    Becker        NaN    494.0
# 4  27007  Minnesota  Beltrami        NaN    627.0
#
#    Years of Potential Life Lost Rate  95% CI - Low  95% CI - High  Z-Score  \
# 0                             5586.0        5515.0         5657.0      NaN
# 1                             7625.0        5759.0         9490.0     0.75
# 2                             5460.0        5178.0         5742.0    -0.47
# 3                             7566.0        6472.0         8659.0     0.72
# 4                            10589.0        9461.0        11716.0     2.42
#
#    YPLL Rate (AIAN)  ...  % Drive Alone (Hispanic) 95% CI - Low  \
# 0           21423.0  ...                                   66.0
# 1               NaN  ...                                    NaN
# 2           14440.0  ...                                   60.0
# 3           21914.0  ...                                    NaN
# 4           26004.0  ...                                   53.0
#
#    % Drive Alone (Hispanic) 95% CI - High  % Drive Alone (white)  \
# 0                                    68.0                   78.0
# 1                                     NaN                    NaN
# 2                                    77.0                   79.0
# 3                                     NaN                   79.0
# 4                                    85.0                   78.0
#
#    % Drive Alone (white) 95% CI - Low  % Drive Alone (white) 95% CI - High  \
# 0                                78.0                                 78.0
# 1                                 NaN                                  NaN
# 2                                78.0                                 80.0
# 3                                76.0                                 81.0
# 4                                75.0                                 80.0
#
#    # Workers who Drive Alone  % Long Commute - Drives Alone  95% CI - Low.19  \
# 0                    2903106                             31               31
# 1                       6248                             34               31
# 2                     188439                             43               41
# 3                      16095                             25               23
# 4                      21098                             19               17
#
#    95% CI - High.19  Z-Score.34
# 0                32         NaN
# 1                37        0.54
# 2                44        1.39
# 3                26       -0.33
# 4                22       -0.85
#
# [5 rows x 249 columns]

# %%
#add leading 0's for counties
minnesota['COUNTYFP'] = minnesota['COUNTYFP'].astype(str)
minnesota['STATEFP'] = minnesota['STATEFP'].astype(str)
minnesota['COUNTYFP'] = minnesota['COUNTYFP'].str.zfill(3)

#concatenate state and county codes
minnesota['fips'] = minnesota['STATEFP'] + minnesota['COUNTYFP']
minnesota['fips'] = minnesota['fips'].astype('int64')
minnesota.head(10)
# Out:
#    Unnamed: 0  OBJECTID       GEOID10       GEOID20 STATEFP COUNTYFP  TRACTCE  \
# 0      125050    125051  2.716310e+11  2.716310e+11      27      163    71003
# 1      125051    125052  2.716310e+11  2.716310e+11      27      163    71003
# 2      125052    125053  2.716310e+11  2.716310e+11      27      163    71003
# 3      125053    125054  2.716310e+11  2.716310e+11      27      163    71006
# 4      125054    125055  2.716310e+11  2.716310e+11      27      163    71006
# 5      125055    125056  2.713110e+11  2.713110e+11      27      131    70800
# 6      125056    125057  2.714500e+11  2.714500e+11      27      145      601
# 7      125057    125058  2.703710e+11  2.703710e+11      27      037    60904
# 8      125058    125059  2.703710e+11  2.703710e+11      27      037    60604
# 9      125059    125060  2.703710e+11  2.703710e+11      27      037    60817
#
#    BLKGRPCE    CSA                     CSA_Name  ...     D5DE    D5DEI  \
# 0         1  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 1         2  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 2         3  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 3         1  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 4         2  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 5         5  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 6         1  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 7         2  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 8         2  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
# 9         4  378.0  Minneapolis-St. Paul, MN-WI  ... -99999.0 -99999.0
#
#    D2A_Ranked  D2B_Ranked  D3B_Ranked  D4A_Ranked  NatWalkInd  Shape_Length  \
# 0          18          15           8           1    8.500000  12371.721880
# 1          18          16           7           1    8.333333   7746.443532
# 2          15           6           9           1    6.833333   9884.396703
# 3          20          20          20           1   13.666667   7814.948545
# 4          20          18          18           1   12.666667  10906.431880
# 5          11           5          16           1    8.333333   3945.373100
# 6          15          20          18           1   12.166667   3645.290542
# 7          20          20          12           1   11.000000   7146.198431
# 8           7          18          10           1    7.833333   7165.978041
# 9           4          11          12           1    6.833333   8984.860085
#
#      Shape_Area   fips
# 0  4.274573e+06  27163
# 1  2.872370e+06  27163
# 2  2.854760e+06  27163
# 3  3.005446e+06  27163
# 4  3.546875e+06  27163
# 5  4.936691e+05  27131
# 6  5.845590e+05  27145
# 7  2.405088e+06  27037
# 8  2.552602e+06  27037
# 9  4.239370e+06  27037
#
# [10 rows x 119 columns]

# %%
#merge main dataset with fips codes dataset
merged_df = pd.merge(minnesota,states,on='fips')

#Choose with columns you want to view (feel free to add more!)
reduced_columns = merged_df[['GEOID20','CSA_Name','name','state','TotPop','NatWalkInd','fips']]
reduced_columns.head(20)
# Out:
#          GEOID20                     CSA_Name               name state  \
# 0   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 1   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 2   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 3   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 4   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 5   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 6   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 7   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 8   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 9   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 10  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 11  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 12  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 13  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 14  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 15  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 16  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 17  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 18  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 19  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
#
#     TotPop  NatWalkInd   fips
# 0     1934    8.500000  27163
# 1      574    8.333333  27163
# 2      998    6.833333  27163
# 3     2506   13.666667  27163
# 4     2350   12.666667  27163
# 5      953    9.500000  27163
# 6      860    5.166667  27163
# 7     1918    5.333333  27163
# 8     1470   12.666667  27163
# 9     1016   10.500000  27163
# 10     762   13.666667  27163
# 11    1378   10.333333  27163
# 12    1621    7.166667  27163
# 13     770   11.166667  27163
# 14    1359    5.500000  27163
# 15    1526    3.833333  27163
# 16    2520    5.833333  27163
# 17    1729   10.666667  27163
# 18    1539   13.166667  27163
# 19    2880    7.666667  27163

# %%
#add buckets for walkability

for index,row in reduced_columns.iterrows():
    if reduced_columns.loc[index, "NatWalkInd"] <= 5.75:
        reduced_columns.loc[index,'Walkability_bucket'] = 'Least Walkable'
    elif reduced_columns.loc[index, "NatWalkInd"] <= 10.5:
        reduced_columns.loc[index,'Walkability_bucket'] ='Below Average Walkability'
    elif reduced_columns.loc[index, "NatWalkInd"] <= 15.25:
        reduced_columns.loc[index,'Walkability_bucket'] = 'Above Average Walkability'
    elif reduced_columns.loc[index, "NatWalkInd"] > 15.25:
        reduced_columns.loc[index,'Walkability_bucket'] = 'Most Walkable'
reduced_columns.head(20)
# Out:
# /var/folders/06/cl4dcprx4mgfy2x504fmy4lw0000gn/T/ipykernel_73531/577720634.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_columns.loc[index,'Walkability_bucket'] ='Below Average Walkability'
#          GEOID20                     CSA_Name               name state  \
# 0   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 1   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 2   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 3   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 4   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 5   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 6   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 7   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 8   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 9   2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 10  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 11  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 12  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 13  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 14  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 15  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 16  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 17  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 18  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
# 19  2.716310e+11  Minneapolis-St. Paul, MN-WI  Washington County    MN
#
#     TotPop  NatWalkInd   fips         Walkability_bucket
# 0     1934    8.500000  27163  Below Average Walkability
# 1      574    8.333333  27163  Below Average Walkability
# 2      998    6.833333  27163  Below Average Walkability
# 3     2506   13.666667  27163  Above Average Walkability
# 4     2350   12.666667  27163  Above Average Walkability
# 5      953    9.500000  27163  Below Average Walkability
# 6      860    5.166667  27163             Least Walkable
# 7     1918    5.333333  27163             Least Walkable
# 8     1470   12.666667  27163  Above Average Walkability
# 9     1016   10.500000  27163  Below Average Walkability
# 10     762   13.666667  27163  Above Average Walkability
# 11    1378   10.333333  27163  Below Average Walkability
# 12    1621    7.166667  27163  Below Average Walkability
# 13     770   11.166667  27163  Above Average Walkability
# 14    1359    5.500000  27163             Least Walkable
# 15    1526    3.833333  27163             Least Walkable
# 16    2520    5.833333  27163  Below Average Walkability
# 17    1729   10.666667  27163  Above Average Walkability
# 18    1539   13.166667  27163  Above Average Walkability
# 19    2880    7.666667  27163  Below Average Walkability

# %%
sums = reduced_columns.groupby(['fips']).sum()['TotPop']
County_sums = pd.DataFrame({'County Population':sums})
weighted_data = pd.merge(reduced_columns,County_sums,on='fips')

weighted_data['weights'] = weighted_data['TotPop'] / weighted_data['County Population']

weighted_data['weightsum'] = weighted_data['NatWalkInd'] * weighted_data['weights']
weighted_data.head()

weighted_index = pd.DataFrame({'Weighted Walk Index':weighted_data.groupby(['fips']).sum()['weightsum']})
weighted_index.sort_values('Weighted Walk Index',ascending=False)
# Out:
#        Weighted Walk Index
# fips
# 27123            12.959863
# 27053            12.202175
# 27027            10.431105
# 27037             9.804645
# 27137             9.133652
# ...                    ...
# 27077             4.956857
# 27153             4.929160
# 27087             4.867054
# 27065             4.619637
# 27029             4.527576
#
# [87 rows x 1 columns]

# %%
health_analysis = pd.merge(weighted_index,health,on='fips')
health_analysis = health_analysis[['County','State','Weighted Walk Index','fips','Average Number of Physically Unhealthy Days', 'Average Number of Mentally Unhealthy Days','Food Environment Index','% Physically Inactive','% Adults with Obesity']]
health_analysis.head()
# Out:
#      County      State  Weighted Walk Index   fips  \
# 0    Aitkin  Minnesota             5.135647  27001
# 1     Anoka  Minnesota             8.824677  27003
# 2    Becker  Minnesota             5.837864  27005
# 3  Beltrami  Minnesota             6.016794  27007
# 4    Benton  Minnesota             6.928409  27009
#
#    Average Number of Physically Unhealthy Days  \
# 0                                          3.7
# 1                                          3.1
# 2                                          3.6
# 3                                          4.1
# 4                                          3.4
#
#    Average Number of Mentally Unhealthy Days  Food Environment Index  \
# 0                                        4.4                     7.4
# 1                                        3.8                     9.1
# 2                                        4.3                     7.8
# 3                                        4.6                     6.8
# 4                                        4.2                     8.3
#
#    % Physically Inactive  % Adults with Obesity
# 0                     23                     34
# 1                     21                     35
# 2                     24                     34
# 3                     23                     35
# 4                     23                     37

# %%
health_analysis.plot(kind='scatter',x='Weighted Walk Index',y='% Physically Inactive')

(slope, intercept, rvalue, pvalue, stderr) = linregress(health_analysis['Weighted Walk Index'],health_analysis['% Physically Inactive'])
line = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
yvalues = health_analysis['Weighted Walk Index'] * slope + intercept
plt.plot(health_analysis['Weighted Walk Index'],yvalues,color='red')
plt.annotate(line,(9,25),fontsize=15,color="red")
plt.xlabel("Walkability Index")
plt.title("County Walkability Index vs Physical Inactivity")
plt.show()

# %%
print(f"R Value = {rvalue}")
# Out:
# R Value = -0.5558514747351887

# %% [markdown]
# Moderate negative correlation. As average walking index per country increases, % of adults reporting being phsyically inavtive decreases.

# %%
health_analysis.plot(kind='scatter',x='Weighted Walk Index',y='Average Number of Mentally Unhealthy Days')
(slope, intercept, rvalue, pvalue, stderr) = linregress(health_analysis['Weighted Walk Index'],health_analysis['Average Number of Mentally Unhealthy Days'])
line = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
yvalues = health_analysis['Weighted Walk Index'] * slope + intercept
plt.plot(health_analysis['Weighted Walk Index'],yvalues,color='red')
plt.annotate(line,(8,5),fontsize=15,color="red")
plt.xlabel("Walkability Index")
plt.title("County Walkability Index vs Poor Mental Health Days")
plt.show()

# %%
print(f"R Value = {rvalue}")
# Out:
# R Value = -0.5903635388860792

# %% [markdown]
# Moderate negative correlation. As average walking index per country increases, the average number of poor mental health days per month decreases.
